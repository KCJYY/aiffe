# %% [markdown]
# ❤주의사항❤
# 15번 터진 파일입니다 제멘탈도 그만큼 터졌단거죠 관심보단 무관심을 주십쇼 멘탈바사삭이라 건들면  터집니다
# feat. 도대체 왜 컴퓨터를 끌떄 혹은 실수로 내렸을때 파일까지 다 나가는걸까 씨ㅣㅣㅣㅣㅣㅣㅣㅣ 저장 자주 누르고 파일좀 바꿔둘껄....

# %%
개인적으론 RFC가  더좋다고 생각함 ACC는 
정확도는 높지만 분산하여 계산하는것보다 신용성이 떨어짐

# %%
from sklearn.datasets import load_digits
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report

# %%
from sklearn.datasets import load_iris

from sklearn.datasets import load_digits

from sklearn.datasets import load_wine

from sklearn.datasets import load_breast_cancer

# %%
wine=load_wine()

# %%
type(wine)
# Out:
# sklearn.utils.Bunch

# %%
wine.keys()
# Out:
# dict_keys(['data', 'target', 'frame', 'target_names', 'DESCR', 'feature_names'])

# %%
FD=wine.data
LD=wine.target
DTN=wine.target_names

# %%
DTN
# Out:
# array(['class_0', 'class_1', 'class_2'], dtype='<U7')

# %%
import pandas as pd

# %%
winedataframe=pd.DataFrame(data=FD,columns=wine.feature_names)

# %%
winedataframe
# Out:
#      alcohol  malic_acid   ash  alcalinity_of_ash  magnesium  total_phenols  \
# 0      14.23        1.71  2.43               15.6      127.0           2.80
# 1      13.20        1.78  2.14               11.2      100.0           2.65
# 2      13.16        2.36  2.67               18.6      101.0           2.80
# 3      14.37        1.95  2.50               16.8      113.0           3.85
# 4      13.24        2.59  2.87               21.0      118.0           2.80
# ..       ...         ...   ...                ...        ...            ...
# 173    13.71        5.65  2.45               20.5       95.0           1.68
# 174    13.40        3.91  2.48               23.0      102.0           1.80
# 175    13.27        4.28  2.26               20.0      120.0           1.59
# 176    13.17        2.59  2.37               20.0      120.0           1.65
# 177    14.13        4.10  2.74               24.5       96.0           2.05
#
# ...

# %%
winedataframe.describe()
# Out:
#           alcohol  malic_acid         ash  alcalinity_of_ash   magnesium  \
# count  178.000000  178.000000  178.000000         178.000000  178.000000
# mean    13.000618    2.336348    2.366517          19.494944   99.741573
# std      0.811827    1.117146    0.274344           3.339564   14.282484
# min     11.030000    0.740000    1.360000          10.600000   70.000000
# 25%     12.362500    1.602500    2.210000          17.200000   88.000000
# 50%     13.050000    1.865000    2.360000          19.500000   98.000000
# 75%     13.677500    3.082500    2.557500          21.500000  107.000000
# max     14.830000    5.800000    3.230000          30.000000  162.000000
#
#        total_phenols  flavanoids  nonflavanoid_phenols  proanthocyanins  \
# count     178.000000  178.000000            178.000000       178.000000
# mean        2.295112    2.029270              0.361854         1.590899
# std         0.625851    0.998859              0.124453         0.572359
# ...

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(FD,
                                              LD,
                                              test_size=0.2,
                                              random_state=10)
print('x_train 개수:',len(x_train),',x_test개수:',len(x_test))
# Out:
# x_train 개수: 142 ,x_test개수: 36

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import classification_report

dtree=DecisionTreeClassifier(random_state=32)
dtree.fit(x_train,y_train)
y_pred=dtree.predict(x_test)
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        10
#            1       1.00      0.89      0.94        18
#            2       0.80      1.00      0.89         8
#
#     accuracy                           0.94        36
#    macro avg       0.93      0.96      0.94        36
# weighted avg       0.96      0.94      0.95        36

# %%
from sklearn.metrics import accuracy_score
from sklearn.ensemble import RandomForestClassifier

RFC=RandomForestClassifier(random_state=100)
RFC.fit(x_train,y_train)
y_pred=RFC.predict(x_test)

accuracy=accuracy_score(y_test,y_pred)
accuracy
# Out:
# 0.9166666666666666

# %%
from sklearn.metrics import confusion_matrix

confusion_matrix(y_test,y_pred)
# Out:
# array([[10,  0,  0],
#        [ 0, 15,  3],
#        [ 0,  0,  8]])
